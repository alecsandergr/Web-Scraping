# %%
import requests
from scrapy.http import TextResponse
# Out:
# /Users/USUARIO/.virtualenvs/web_scrapping/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def get_response(endpoint: str = '/courses-all'):
    url = 'https://www.datacamp.com' + endpoint
    response = requests.get(url, headers={'User-Agent': 'XYZ/3.0'})
    response = TextResponse(body=response.content, url=url)
    return response

def generate_links(response):
    course_blocks = response.css('div.css-3undxp-HitCard')
    course_links = course_blocks.xpath('./a/@href')
    links_to_follow = course_links.extract()
    for link in links_to_follow:
        yield get_response(link)

def get_info_from_course(response):
    for link_resp in generate_links(response):

        # Direct to the course title text
        crs_title = link_resp.css('h1.css-7ymucl-CourseShowPage::text')
        # crs_title = link_resp.xpath('//h1[@class="css-7ymucl-CourseShowPage"]/text()')
        # Extract and clean the course title text
        crs_title_ext = crs_title.extract_first().strip()
        # Direct to the chapter description
        ch_desc = link_resp.css('p.css-hnday4-CourseShowPage::text')
        # Extract and clean the chapter description
        ch_desc_ext = ch_desc.extract_first().strip()
        # Direct to the chapter titles text
        ch_titles = link_resp.css('h3.css-172ju3k-Box::text')
        # ch_titles = link_resp.xpath('//h3[@class="css-172ju3k-Box"]/text()')
        # Extract and clean the chapter titles
        ch_titles_ext = [t.strip() for t in ch_titles.extract()]

        dc_dict[crs_title_ext] = {'Description': ch_desc_ext, 'Chapters': ch_titles_ext}
        print(crs_title_ext, ch_desc_ext, ch_titles_ext, '\n', sep='\n')

def scrap_datacamp():
    response = get_response()
    get_info_from_course(response)

# %%
dc_dict = {}

response = get_response()
get_info_from_course(response)
# Out:
# Introduction to Python
# Master the basics of data analysis with Python in just four hours. This online course will introduce the Python interface and explore popular packages.
# ['Python Basics', 'Python Lists', 'Functions and Packages', 'NumPy']
#
#
# Introduction to SQL
# Learn how to create and query relational databases using SQL in just two hours.
# ['Relational Databases', 'Querying']
#
#
# Introduction to ChatGPT
# Learn how to use ChatGPT. Discover best practices for writing prompts and explore common business use cases for the powerful AI tool.
# ['Interacting with ChatGPT', 'Adopting ChatGPT']
#
#
# Understanding Data Science
# An introduction to data science with no coding involved.
# ['Introduction to Data Science', 'Data Collection and Storage', 'Preparation, Exploration, and Visualization', 'Experimentation and Prediction']
#
#
# Introduction to R
# Master the basics of data analysis in R, including vectors, lists, and data frames, and practice R with real data sets.
# ['Intro to basics', 'Vectors', 'Matrices', 'Factors', 'Data frames', 'Lists']
#
#
# Intermediate Python
# Level up your data science skills by creating visualizations using Matplotlib and manipulating DataFrames with pandas.
# ['Matplotlib', 'Dictionaries & Pandas', 'Logic, Control Flow and Filtering', 'Loops', 'Case Study: Hacker Statistics']
#
#
# Intermediate SQL
# Accompanied at every step with hands-on practice queries, this course teaches you everything you need to know to analyze data using your own SQL code today!
# ['Selecting Data', 'Filtering Records', 'Aggregate Functions', 'Sorting and Grouping']
#
#
# Introduction to Power BI
# Master the Power BI basics and learn to use the data visualization software to build impactful reports.
# ['Getting Started with Power BI', 'Transforming Data', 'Visualizing Data', 'Filtering']
#
#
# Data Manipulation with pandas
# Learn how to import and clean data, calculate statistics, and create visualizations with pandas.
# ['Transforming DataFrames', 'Aggregating DataFrames', 'Slicing and Indexing DataFrames', 'Creating and Visualizing DataFrames']
#
#
# Joining Data in SQL
# Level up your SQL knowledge and learn to join tables together, apply relational set theory, and work with subqueries.
# ['Introducing Inner Joins', 'Outer Joins, Cross Joins and Self Joins', 'Set Theory for SQL Joins', 'Subqueries']
#
#
# Supervised Learning with scikit-learn
# Grow your machine learning skills with scikit-learn in Python. Use real-world datasets in this interactive course and learn how to make powerful predictions!
# ['Classification', 'Regression', 'Fine-Tuning Your Model', 'Preprocessing and Pipelines']
#
#
# Understanding Data Engineering
# Discover how data engineers lay the groundwork that makes data science possible. No coding involved!
# ['What is data engineering?', 'Storing data', 'Moving and processing data']
#
#
# Data Manipulation in SQL
# Master the complex SQL queries necessary to answer a wide variety of data science questions and prepare robust data sets for analysis in PostgreSQL.
# ["We'll take the CASE", 'Short and Simple Subqueries', 'Correlated Queries, Nested Queries, and Common Table Expressions', 'Window Functions']
#
#
# Data Analysis in Excel
# Build real-world Excel skills in just 4 hours. This course will show you time-saving shortcuts and essential functions.
# ['Exploring Data', 'Preparing Data', 'Analyzing Data']
#
#
# Introduction to Tableau
# Start your Tableau journey with our Introduction to Tableau course. Discover Tableau basics such as its features and dashboards.
# ['Getting Started with Tableau', 'Building and Customizing Visualizations', 'Digging Deeper', 'Presenting Your Data']
#
#
# Introduction to Statistics in Python
# Grow your statistical skills and learn how to collect, analyze, and draw accurate conclusions from data using Python.
# ['Summary Statistics', 'Random Numbers and Probability', 'More Distributions and the Central Limit Theorem', 'Correlation and Experimental Design']
#
#
# Joining Data with pandas
# Learn to combine data from multiple tables by joining data together using pandas.
# ['Data Merging Basics', 'Merging Tables With Different Join Types', 'Advanced Merging and Concatenating', 'Merging Ordered and Time-Series Data']
#
#
# Python Data Science Toolbox (Part 1)
# Learn the art of writing your own functions in Python, as well as key concepts like scoping and error handling.
# ['Writing your own functions', 'Default arguments, variable-length arguments and scope', 'Lambda functions and error-handling']
#
#
# Introduction to Excel
# Master the Excel basics and learn to use this spreadsheet tool to conduct impactful analysis.
# ['Getting started with Excel', 'Managing data and applying aggregate functions', 'Other functions and visualizing data']
#
#
# Exploratory Data Analysis in Python
# Learn how to explore, visualize, and extract insights from data using exploratory data analysis (EDA) in Python.
# ['Getting to Know a Dataset', 'Data Cleaning and Imputation', 'Relationships in Data', 'Turning Exploratory Analysis into Action']
#
#
# Introduction to DAX in Power BI
# Enhance your Power BI knowledge, by learning the fundamentals of Data Analysis Expressions (DAX) such as calculated columns, tables, and measures.
# ['Getting Started with DAX', 'Context in DAX Formulas', 'Working with Dates']
#
#
# Exploratory Data Analysis in SQL
# Learn how to explore what's available in a database: the tables, relationships between them, and data stored in them.
# ["What's in the database?", 'Summarizing and aggregating numeric data', 'Exploring categorical data and unstructured text', 'Working with dates and timestamps']
#
#
# Understanding Data Visualization
# An introduction to data visualization with no coding involved.
# ['Visualizing distributions', 'Visualizing two variables', 'The color and the shape', "99 problems but a plot ain't one of them"]
#
#
# Introduction to Importing Data in Python
# Learn to import data into Python from various sources, such as Excel, SQL, SAS and right from the web.
# ['Introduction and flat files', 'Importing data from other file types', 'Working with relational databases in Python']
#
#
# Data Science for Business
# Learn about data science for managers and businesses and how to use data to strengthen your organization.
# ['Introduction to Data Science', 'Data Collection and Storage', 'Analysis and Visualization', 'Prediction']
#
#
# Introduction to Data Visualization with Seaborn
# Learn how to create informative and attractive visualizations in Python using the Seaborn library.
# ['Introduction to Seaborn', 'Visualizing Two Quantitative Variables', 'Visualizing a Categorical and a Quantitative Variable', 'Customizing Seaborn Plots']
#
#
# Understanding Machine Learning
# An introduction to machine learning with no coding involved.
# ['What is Machine Learning?', 'Machine Learning Models', 'Deep Learning']
#
#
# Introduction to Data Visualization with Matplotlib
# Learn how to create, customize, and share data visualizations using Matplotlib.
# ['Introduction to Matplotlib', 'Plotting time-series', 'Quantitative comparisons and statistical visualizations', 'Sharing visualizations with others']
#
#
# Introduction to Statistics
# Learn the fundamentals of statistics, including measures of center and spread, probability distributions, and hypothesis testing with no coding involved!
# ['Summary Statistics', 'Probability and distributions', 'More Distributions and the Central Limit Theorem', 'Correlation and Hypothesis Testing']
#
#
# Python Data Science Toolbox (Part 2)
# Continue to build your modern Data Science skills by learning about iterators and list comprehensions.
# ['Using iterators in PythonLand', 'List comprehensions and generators', 'Bringing it all together!']

# %%
for course, course_items in dc_dict.items():
    print(f'Course: {course}')
    print(f'Description: {course_items["Description"]}')
    for i, chapter in enumerate(course_items['Chapters'], start=1):
        print(f'    Chapter {i}: {chapter}')
    print('')
# Out:
# Course: Introduction to Python
# Description: Master the basics of data analysis with Python in just four hours. This online course will introduce the Python interface and explore popular packages.
#     Chapter 1: Python Basics
#     Chapter 2: Python Lists
#     Chapter 3: Functions and Packages
#     Chapter 4: NumPy
#
# Course: Introduction to SQL
# Description: Learn how to create and query relational databases using SQL in just two hours.
#     Chapter 1: Relational Databases
#     Chapter 2: Querying
#
# Course: Introduction to ChatGPT
# Description: Learn how to use ChatGPT. Discover best practices for writing prompts and explore common business use cases for the powerful AI tool.
#     Chapter 1: Interacting with ChatGPT
#     Chapter 2: Adopting ChatGPT
#
# Course: Understanding Data Science
# Description: An introduction to data science with no coding involved.
#     Chapter 1: Introduction to Data Science
#     Chapter 2: Data Collection and Storage
#     Chapter 3: Preparation, Exploration, and Visualization
#     Chapter 4: Experimentation and Prediction
#
# Course: Introduction to R
# Description: Master the basics of data analysis in R, including vectors, lists, and data frames, and practice R with real data sets.
#     Chapter 1: Intro to basics
#     Chapter 2: Vectors
#     Chapter 3: Matrices
#     Chapter 4: Factors
#     Chapter 5: Data frames
#     Chapter 6: Lists
#
# Course: Intermediate Python
# Description: Level up your data science skills by creating visualizations using Matplotlib and manipulating DataFrames with pandas.
#     Chapter 1: Matplotlib
#     Chapter 2: Dictionaries & Pandas
#     Chapter 3: Logic, Control Flow and Filtering
#     Chapter 4: Loops
#     Chapter 5: Case Study: Hacker Statistics
#
# Course: Intermediate SQL
# Description: Accompanied at every step with hands-on practice queries, this course teaches you everything you need to know to analyze data using your own SQL code today!
#     Chapter 1: Selecting Data
#     Chapter 2: Filtering Records
#     Chapter 3: Aggregate Functions
#     Chapter 4: Sorting and Grouping
#
# Course: Introduction to Power BI
# Description: Master the Power BI basics and learn to use the data visualization software to build impactful reports.
#     Chapter 1: Getting Started with Power BI
#     Chapter 2: Transforming Data
#     Chapter 3: Visualizing Data
#     Chapter 4: Filtering
#
# Course: Data Manipulation with pandas
# Description: Learn how to import and clean data, calculate statistics, and create visualizations with pandas.
#     Chapter 1: Transforming DataFrames
#     Chapter 2: Aggregating DataFrames
#     Chapter 3: Slicing and Indexing DataFrames
#     Chapter 4: Creating and Visualizing DataFrames
#
# Course: Joining Data in SQL
# Description: Level up your SQL knowledge and learn to join tables together, apply relational set theory, and work with subqueries.
#     Chapter 1: Introducing Inner Joins
#     Chapter 2: Outer Joins, Cross Joins and Self Joins
#     Chapter 3: Set Theory for SQL Joins
#     Chapter 4: Subqueries
#
# Course: Supervised Learning with scikit-learn
# Description: Grow your machine learning skills with scikit-learn in Python. Use real-world datasets in this interactive course and learn how to make powerful predictions!
#     Chapter 1: Classification
#     Chapter 2: Regression
#     Chapter 3: Fine-Tuning Your Model
#     Chapter 4: Preprocessing and Pipelines
#
# Course: Understanding Data Engineering
# Description: Discover how data engineers lay the groundwork that makes data science possible. No coding involved!
#     Chapter 1: What is data engineering?
#     Chapter 2: Storing data
#     Chapter 3: Moving and processing data
#
# Course: Data Manipulation in SQL
# Description: Master the complex SQL queries necessary to answer a wide variety of data science questions and prepare robust data sets for analysis in PostgreSQL.
#     Chapter 1: We'll take the CASE
#     Chapter 2: Short and Simple Subqueries
#     Chapter 3: Correlated Queries, Nested Queries, and Common Table Expressions
#     Chapter 4: Window Functions
#
# Course: Data Analysis in Excel
# Description: Build real-world Excel skills in just 4 hours. This course will show you time-saving shortcuts and essential functions.
#     Chapter 1: Exploring Data
#     Chapter 2: Preparing Data
#     Chapter 3: Analyzing Data
#
# Course: Introduction to Tableau
# Description: Start your Tableau journey with our Introduction to Tableau course. Discover Tableau basics such as its features and dashboards.
#     Chapter 1: Getting Started with Tableau
#     Chapter 2: Building and Customizing Visualizations
#     Chapter 3: Digging Deeper
#     Chapter 4: Presenting Your Data
#
# Course: Introduction to Statistics in Python
# Description: Grow your statistical skills and learn how to collect, analyze, and draw accurate conclusions from data using Python.
#     Chapter 1: Summary Statistics
#     Chapter 2: Random Numbers and Probability
#     Chapter 3: More Distributions and the Central Limit Theorem
#     Chapter 4: Correlation and Experimental Design
#
# Course: Joining Data with pandas
# Description: Learn to combine data from multiple tables by joining data together using pandas.
#     Chapter 1: Data Merging Basics
#     Chapter 2: Merging Tables With Different Join Types
#     Chapter 3: Advanced Merging and Concatenating
#     Chapter 4: Merging Ordered and Time-Series Data
#
# Course: Python Data Science Toolbox (Part 1)
# Description: Learn the art of writing your own functions in Python, as well as key concepts like scoping and error handling.
#     Chapter 1: Writing your own functions
#     Chapter 2: Default arguments, variable-length arguments and scope
#     Chapter 3: Lambda functions and error-handling
#
# Course: Introduction to Excel
# Description: Master the Excel basics and learn to use this spreadsheet tool to conduct impactful analysis.
#     Chapter 1: Getting started with Excel
#     Chapter 2: Managing data and applying aggregate functions
#     Chapter 3: Other functions and visualizing data
#
# Course: Exploratory Data Analysis in Python
# Description: Learn how to explore, visualize, and extract insights from data using exploratory data analysis (EDA) in Python.
#     Chapter 1: Getting to Know a Dataset
#     Chapter 2: Data Cleaning and Imputation
#     Chapter 3: Relationships in Data
#     Chapter 4: Turning Exploratory Analysis into Action
#
# Course: Introduction to DAX in Power BI
# Description: Enhance your Power BI knowledge, by learning the fundamentals of Data Analysis Expressions (DAX) such as calculated columns, tables, and measures.
#     Chapter 1: Getting Started with DAX
#     Chapter 2: Context in DAX Formulas
#     Chapter 3: Working with Dates
#
# Course: Exploratory Data Analysis in SQL
# Description: Learn how to explore what's available in a database: the tables, relationships between them, and data stored in them.
#     Chapter 1: What's in the database?
#     Chapter 2: Summarizing and aggregating numeric data
#     Chapter 3: Exploring categorical data and unstructured text
#     Chapter 4: Working with dates and timestamps
#
# Course: Understanding Data Visualization
# Description: An introduction to data visualization with no coding involved.
#     Chapter 1: Visualizing distributions
#     Chapter 2: Visualizing two variables
#     Chapter 3: The color and the shape
#     Chapter 4: 99 problems but a plot ain't one of them
#
# Course: Introduction to Importing Data in Python
# Description: Learn to import data into Python from various sources, such as Excel, SQL, SAS and right from the web.
#     Chapter 1: Introduction and flat files
#     Chapter 2: Importing data from other file types
#     Chapter 3: Working with relational databases in Python
#
# Course: Data Science for Business
# Description: Learn about data science for managers and businesses and how to use data to strengthen your organization.
#     Chapter 1: Introduction to Data Science
#     Chapter 2: Data Collection and Storage
#     Chapter 3: Analysis and Visualization
#     Chapter 4: Prediction
#
# Course: Introduction to Data Visualization with Seaborn
# Description: Learn how to create informative and attractive visualizations in Python using the Seaborn library.
#     Chapter 1: Introduction to Seaborn
#     Chapter 2: Visualizing Two Quantitative Variables
#     Chapter 3: Visualizing a Categorical and a Quantitative Variable
#     Chapter 4: Customizing Seaborn Plots
#
# Course: Understanding Machine Learning
# Description: An introduction to machine learning with no coding involved.
#     Chapter 1: What is Machine Learning?
#     Chapter 2: Machine Learning Models
#     Chapter 3: Deep Learning
#
# Course: Introduction to Data Visualization with Matplotlib
# Description: Learn how to create, customize, and share data visualizations using Matplotlib.
#     Chapter 1: Introduction to Matplotlib
#     Chapter 2: Plotting time-series
#     Chapter 3: Quantitative comparisons and statistical visualizations
#     Chapter 4: Sharing visualizations with others
#
# Course: Introduction to Statistics
# Description: Learn the fundamentals of statistics, including measures of center and spread, probability distributions, and hypothesis testing with no coding involved!
#     Chapter 1: Summary Statistics
#     Chapter 2: Probability and distributions
#     Chapter 3: More Distributions and the Central Limit Theorem
#     Chapter 4: Correlation and Hypothesis Testing
#
# Course: Python Data Science Toolbox (Part 2)
# Description: Continue to build your modern Data Science skills by learning about iterators and list comprehensions.
#     Chapter 1: Using iterators in PythonLand
#     Chapter 2: List comprehensions and generators
#     Chapter 3: Bringing it all together!
